# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://wuzzuf.net/search/jobs/?q=Machine%20learning&a=hpb%27')
src = page.content
src
# Out:
# b'<!DOCTYPE html>\n<html lang="en" translate="no">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, shrink-to-fit=no">\n    <meta http-equiv="expires" content="Thu Dec 08 2022 18:30:44 GMT+0200" />\n\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate">\n    <meta name="googlebot" content="notranslate">\n    <title data-react-helmet="true">Job Search | WUZZUF</title>\n\n<meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" name="description" content="Searching for jobs in Egypt? Wuzzuf helps you in your online job search to find Jobs in Egypt and Middle East. Choose the right job using our online recruitment services."/><meta data-react-helmet="true" name="keywords" content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employm
# ...

# %%
soup = BeautifulSoup(src, 'lxml')

# %%
jobs =soup.find_all("div",class_="css-1gatmva e1v1l3u10")

# %%
import pandas as pd
df = pd.DataFrame(columns = ["job_title", "company_name","area","city","country","job_type" ,"job_state","exp_level", "exp_years","job_category","skills","posted"])
df
# Out:
# Empty DataFrame
# Columns: [job_title, company_name, area, city, country, job_type, job_state, exp_level, exp_years, job_category, skills, posted]
# Index: []

# %%
import numpy as np

# Example extracted text
exp_text = jobs[0].find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[1]

def parse_exp_years(exp_text):
    try:
        # Extract years from the text
        years = exp_text.split(" Yrs of Exp")[0]

        # Check if the years part contains a range
        if '-' in years:
            start_year, end_year = years.split('-')
            start_year = start_year.strip()
            end_year = end_year.strip()

            # Check if both start and end year are valid numbers
            if start_year.isdigit() and end_year.isdigit():
                return exp_text
            else:
                return np.nan
        else:
            # Check if the single year value is a valid number
            if years.strip().isdigit():
                return exp_text
            else:
                return np.nan
    except Exception as e:
        return np.nan

exp_years = parse_exp_years(exp_text)
print(exp_years)
# Out:
# 3 - 15 Yrs of Exp

# %%
#Machine Learning jobs
#iterating on every page
for i in range(68):
    pages = requests.get(f"https://wuzzuf.net/search/jobs/?a=hpb%7Cspbg&q=machine%20learning&start={i}")
    src = pages.content
    soup = BeautifulSoup(src, 'lxml')
    jobs =soup.find_all("div",class_="css-1gatmva e1v1l3u10")
    for job in jobs:
        job_title=job.find_all("h2",class_="css-m604qf")[0].text
        company_name = job.find_all("div", class_ = "css-d7j1kk")[0].text.split(" - ")[0]
        try:

            area = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-3]

        except:
            area="Not mentioned"
        city = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-2]
        country = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-1]
        try:
            job_state = jobs[1].find_all("span", class_ = "css-o1vzmt eoyjyou0")[0].text

        except:
             job_state = "Not Mentioned"
        job_type = jobs[0].find_all("span", class_ = "css-1ve4b75 eoyjyou0")[0].text
        exp_level = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[0]
        try:
            posted = job.find_all("div", class_ = "css-do6t5g")[0].text
        except:
            posted = job.find_all("div", class_ = "css-4c4ojb")[0].text
        job_category= job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[2]
        skills = " ".join(job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[5:])
        exp_text = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[1]
        exp_years = parse_exp_years(exp_text)


        df.loc[len(df.index)] =[job_title, company_name,area,city,country,job_type ,job_state,exp_level,exp_years,job_category,skills,posted]

# %%
#AI jobs
#iterating on every page
for i in range(115):
    pages = requests.get(f"https://wuzzuf.net/search/jobs/?a=navbl&q=AI&start={i}")
    src = pages.content
    soup = BeautifulSoup(src, 'lxml')
    jobs =soup.find_all("div",class_="css-1gatmva e1v1l3u10")
    for job in jobs:
        job_title=job.find_all("h2",class_="css-m604qf")[0].text
        company_name = job.find_all("div", class_ = "css-d7j1kk")[0].text.split(" - ")[0]
        try:

            area = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-3]

        except:
            area="Not mentioned"
        city = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-2]
        country = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-1]
        try:
            job_state = jobs[1].find_all("span", class_ = "css-o1vzmt eoyjyou0")[0].text

        except:
             job_state = "Not Mentioned"
        job_type = jobs[0].find_all("span", class_ = "css-1ve4b75 eoyjyou0")[0].text
        exp_level = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[0]
        try:
            posted = job.find_all("div", class_ = "css-do6t5g")[0].text
        except:
            posted = job.find_all("div", class_ = "css-4c4ojb")[0].text
        job_category= job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[2]
        skills = " ".join(job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[5:])
        exp_text = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[1]
        exp_years = parse_exp_years(exp_text)


        df.loc[len(df.index)] =[job_title, company_name,area,city,country,job_type ,job_state,exp_level,exp_years,job_category,skills,posted]

# %%
#software jobs
#iterating on every page
for i in range(4000):
    pages = requests.get(f"https://wuzzuf.net/search/jobs/?a=navbg%7Cspbg&q=software&start={i}")
    src = pages.content
    soup = BeautifulSoup(src, 'lxml')
    jobs =soup.find_all("div",class_="css-1gatmva e1v1l3u10")
    for job in jobs:
        job_title=job.find_all("h2",class_="css-m604qf")[0].text
        company_name = job.find_all("div", class_ = "css-d7j1kk")[0].text.split(" - ")[0]
        try:

            area = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-3]

        except:
            area="Not mentioned"
        city = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-2]
        country = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-1]
        try:
            job_state = jobs[1].find_all("span", class_ = "css-o1vzmt eoyjyou0")[0].text

        except:
             job_state = "Not Mentioned"
        job_type = jobs[0].find_all("span", class_ = "css-1ve4b75 eoyjyou0")[0].text
        exp_level = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[0]
        try:
            posted = job.find_all("div", class_ = "css-do6t5g")[0].text
        except:
            posted = job.find_all("div", class_ = "css-4c4ojb")[0].text
        job_category= job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[2]
        skills = " ".join(job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[5:])
        exp_text = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[1]
        exp_years = parse_exp_years(exp_text)


        df.loc[len(df.index)] =[job_title, company_name,area,city,country,job_type ,job_state,exp_level,exp_years,job_category,skills,posted]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4234 entries, 0 to 4233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     4234 non-null   object
#  1   company_name  4234 non-null   object
#  2   area          4234 non-null   object
#  3   city          4234 non-null   object
#  4   country       4234 non-null   object
#  5   job_type      4234 non-null   object
#  6   job_state     4234 non-null   object
#  7   exp_level     4234 non-null   object
#  8   exp_years     2370 non-null   object
#  9   job_category  4234 non-null   object
#  10  skills        4234 non-null   object
#  11  posted        4234 non-null   object
# dtypes: object(12)
# memory usage: 430.0+ KB

# %%
df.head(30)
# Out:
#                                             job_title  \
# 0     AI Data Science and Machine Learning Instructor
# 1                           Machine Learning Engineer
# 2                           Machine Learning Engineer
# 3                                  Senior AI Engineer
# 4                                         AI Engineer
# 5              Senior Developer - Enterprise Software
# 6             Second Level Technical Support Engineer
# 7                          AI and Robotics Instructor
# 8                                     DevOps Engineer
# 9   Graduate Internship: Enterprise Software Engin...
# 10      Learning & Development Digitalization Manager
# 11                                          AI Intern
# 12       Learning & Development Management Supervisor
# 13                                     Data Scientist
# 14                         AI Engineer - Saudi Arabia
# 15                                  AI Engineer - UAE
# ...

# %%
#training & instructor jobs
#iterating on every page
for i in range(100):
    pages = requests.get(f"https://wuzzuf.net/a/Training-Instructor-Jobs-in-Egypt?start={i}")
    src = pages.content
    soup = BeautifulSoup(src, 'lxml')
    jobs =soup.find_all("div",class_="css-1gatmva e1v1l3u10")
    for job in jobs:
        job_title=job.find_all("h2",class_="css-m604qf")[0].text
        company_name = job.find_all("div", class_ = "css-d7j1kk")[0].text.split(" - ")[0]
        try:

            area = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-3]

        except:
            area="Not mentioned"
        city = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-2]
        country = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-1]
        try:
            job_state = jobs[1].find_all("span", class_ = "css-o1vzmt eoyjyou0")[0].text

        except:
             job_state = "Not Mentioned"
        job_type = jobs[0].find_all("span", class_ = "css-1ve4b75 eoyjyou0")[0].text
        exp_level = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[0]
        try:
            posted = job.find_all("div", class_ = "css-do6t5g")[0].text
        except:
            posted = job.find_all("div", class_ = "css-4c4ojb")[0].text
        job_category= job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[2]
        skills = " ".join(job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[5:])
        exp_text = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[1]
        exp_years = parse_exp_years(exp_text)


        df.loc[len(df.index)] =[job_title, company_name,area,city,country,job_type ,job_state,exp_level,exp_years,job_category,skills,posted]

# %%
#HR jobs
#iterating on every page
for i in range(500):
    pages = requests.get(f"https://wuzzuf.net/a/Human-Resources-HR-Jobs-in-Egypt?start={i}")
    src = pages.content
    soup = BeautifulSoup(src, 'lxml')
    jobs =soup.find_all("div",class_="css-1gatmva e1v1l3u10")
    for job in jobs:
        job_title=job.find_all("h2",class_="css-m604qf")[0].text
        company_name = job.find_all("div", class_ = "css-d7j1kk")[0].text.split(" - ")[0]
        try:

            area = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-3]

        except:
            area="Not mentioned"
        city = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-2]
        country = job.find_all("span", class_ = "css-5wys0k")[0].text.split(", ")[-1]
        try:
            job_state = jobs[1].find_all("span", class_ = "css-o1vzmt eoyjyou0")[0].text

        except:
             job_state = "Not Mentioned"
        job_type = jobs[0].find_all("span", class_ = "css-1ve4b75 eoyjyou0")[0].text
        exp_level = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[0]
        try:
            posted = job.find_all("div", class_ = "css-do6t5g")[0].text
        except:
            posted = job.find_all("div", class_ = "css-4c4ojb")[0].text
        job_category= job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[2]
        skills = " ".join(job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[5:])
        exp_text = job.find_all("div", class_ = "css-1lh32fc")[0].next_sibling.text.split(" · ")[1]
        exp_years = parse_exp_years(exp_text)


        df.loc[len(df.index)] =[job_title, company_name,area,city,country,job_type ,job_state,exp_level,exp_years,job_category,skills,posted]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4826 entries, 0 to 4825
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     4826 non-null   object
#  1   company_name  4826 non-null   object
#  2   area          4826 non-null   object
#  3   city          4826 non-null   object
#  4   country       4826 non-null   object
#  5   job_type      4826 non-null   object
#  6   job_state     4826 non-null   object
#  7   exp_level     4826 non-null   object
#  8   exp_years     2884 non-null   object
#  9   job_category  4826 non-null   object
#  10  skills        4826 non-null   object
#  11  posted        4826 non-null   object
# dtypes: object(12)
# memory usage: 490.1+ KB

# %%
df.head(20)
# Out:
#                                             job_title  \
# 0     AI Data Science and Machine Learning Instructor
# 1                           Machine Learning Engineer
# 2                           Machine Learning Engineer
# 3                                  Senior AI Engineer
# 4                                         AI Engineer
# 5              Senior Developer - Enterprise Software
# 6             Second Level Technical Support Engineer
# 7                          AI and Robotics Instructor
# 8                                     DevOps Engineer
# 9   Graduate Internship: Enterprise Software Engin...
# 10      Learning & Development Digitalization Manager
# 11                                          AI Intern
# 12       Learning & Development Management Supervisor
# 13                                     Data Scientist
# 14                         AI Engineer - Saudi Arabia
# 15                                  AI Engineer - UAE
# ...

# %%
df.to_csv("WUZZUF_finall.csv")
